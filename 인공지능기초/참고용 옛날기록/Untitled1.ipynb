# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p '/content/drive/MyDrive/colab_test'

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.rand(10,5))

df.to_csv("/content/drive/MyDrive/colab_test/dfs.csv")

# !ls -Fcal '/content/drive/MyDrive/colab_test'
# Out:
# total 1
# -rw------- 1 root root 998 Sep 13 11:16 dfs.csv
